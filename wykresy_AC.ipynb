# %%
import os
import glob
import math
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
name = 'Wykres'

for filename in glob.glob('*.csv'):
    #print(str(filename))
    i=0
        
    with open(filename, 'r') as f:
        aTable = []
        bTable = []
        cTable = []
        dTable = []
        
        for line in f:
            i=i+1
            
            if i >= 23:
                a,b,c,d,e,f = line.split(',')
                a=float(a)
                b=float(b)
                c=float(c)
                d=float(d)
                aTable.append(a)
                bTable.append(b)
                cTable.append(c)
                dTable.append(d)
            
        name, rozsz = filename.split(".")
        fig = plt.figure()
        plt.title(name)
        plt.xlabel('U_in [V]')
        plt.ylabel('U_out [V]')

        plt.scatter(cTable,dTable)

        plt.show()
        
        #name, rozsz = filename.split(".")
        fig.savefig(name + "h")

# %%
name = 'Wykres'

for filename in glob.glob('*.csv'):
    #print(str(filename))
    i=0
        
    with open(filename, 'r') as f:
        aTable = []
        bTable = []
        cTable = []
        dTable = []
        
        for line in f:
            i=i+1
            
            if i >= 23:
                a,b,c,d,e,f = line.split(',')
                a=float(a)
                b=float(b)
                c=float(c)
                d=float(d)
                aTable.append(a)
                bTable.append(b)
                cTable.append(c)
                dTable.append(d)
            
        name, rozsz = filename.split(".")
        fig = plt.figure()
        #plt.xticks(np.arange(min(bTable), max(bTable), 1.0))
        plt.subplot(211)
        plt.title(name)
        plt.plot(bTable, cTable)
        fig.tight_layout()
        plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
        plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
        plt.xlabel('t [s]')
        plt.ylabel('U [V]')
        plt.subplot(212)
        plt.plot(bTable, dTable)
        fig.tight_layout()
        plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
        plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
        plt.xlabel('t [s]')
        plt.ylabel('U [V]')
        plt.subplots_adjust(left=None, bottom=0.2, right=None, top=None, wspace=None, hspace=None)
        fig.savefig(name)

# %%
name = 'Wykres'

for filename in glob.glob('*.csv'):
    #print(str(filename))
    i=0
        
    with open(filename, 'r') as f:
        aTable = []
        bTable = []
        cTable = []
        dTable = []
        
        for line in f:
            i=i+1
            
            if i >= 23:
                a,b,c,d,e,f = line.split(',')
                a=float(a)
                b=float(b)
                c=float(c)
                d=float(d)
                aTable.append(a)
                bTable.append(b)
                cTable.append(c)
                dTable.append(d)
            
        name, rozsz = filename.split(".")
        fig = plt.figure()
        plt.title(name)
        fig = plt.plot(x=[bTable], y=[cTable, dTable])
        plt.xlabel('t [s]')
        plt.ylabel('U [V]')
        #plt.ticklabel_format(axis='y', style='sci', scilimits=(-2,2))
        plt.show()     
        plt.savefig(name)
